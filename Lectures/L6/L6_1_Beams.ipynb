# %% [markdown]
# # CEE6501 — Lecture 6.1
#
# ## Beams

# %% [markdown]
# ## Learning Objectives
#
# By the end of this lecture, you will be able to:
#
# - Text
# - Text

# %% [markdown]
# ## Agenda
#
# 1. Text
# 2. Text

# %% [markdown]
# ## Part 1 —
#
# > Text

# %% [markdown]
# ### Text

# %% [markdown]
# ## Wrap-Up
#
# Today you started
#
# Next Lecture: continue
