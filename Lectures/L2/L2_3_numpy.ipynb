# %% [markdown]
# # CEE6501 — Lecture 2
#
# ## Implementing Matrix Methods in Python (Section 3)

# %% [markdown]
# ## Learning Objectives (Section 3)
#
# By the end of this section, you will:
# - Use **Python / NumPy** to represent vectors and matrices
# - Perform matrix operations and solve linear systems programmatically
# - Avoid common pitfalls such as **explicit matrix inversion**
# - Verify results using computational checks and simple test cases
