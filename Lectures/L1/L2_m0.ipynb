# %% [markdown]
# # 🧪 Week 1, Lecture 2: Introduction to Python & Jupyter
#
# Welcome! In this lecture we'll learn how to write and run Python using Jupyter Notebooks within VS Code and in the browser. We'll cover:
#
# - How Jupyter Notebooks work
# - Basic Python syntax and structures
# - Classes and object-oriented programming
# - Conda environments and packages
# - Tutorials for NumPy, SciPy, Matplotlib, and Pandas

# %% [markdown]
# # 🗂️ Module 0: What is Jupyter Notebook?
#
# Jupyter Notebooks are **interactive computational documents** that combine code, visual output, text, equations, and more in a single file (`.ipynb`). They're widely used in data science, education, scientific research, and rapid prototyping.
#
# The name **Jupyter** comes from **Ju**lia, **Pyt**hon, and **R**, though the project now supports many languages via **kernels**. In this course, we'll be using Python exclusively.

# %% [markdown]
# ✅ Key Features
#
# - 🔁 **Executable code** in small chunks (cells)
# - 📝 **Markdown** cells for formatting, descriptions, and embedded LaTeX math
# - 📊 **Inline visualizations** using libraries like `matplotlib`, `plotly`, etc.
# - 🔍 **Immediate feedback**: great for learning, debugging, and exploration

# %% [markdown]
# ## 💡 Why Use Jupyter in This Course?
#
# - Allows you to write code in steps and test incrementally
# - Encourages **documentation** and **code explanation** side by side
# - Makes it easier to **present and share** your work (e.g., in reports or papers)
# - Ideal for **data exploration, plotting, and prototyping** algorithms
# - Fully integrated with **VS Code**, giving you an IDE experience

# %% [markdown]
# ## 🧠 How It Works
#
# Jupyter separates the **frontend** (the notebook interface) from the **backend** (the kernel that runs code).
#
# - **Frontend (UI):** Where you write code and see results (e.g., VS Code, JupyterLab)
# - **Kernel:** The process that runs your code (Python kernel in our case)
# - When you run a code cell, the frontend sends the code to the kernel and displays the output inline

# %% [markdown]
# ## 💻 How to Use in VS Code
#
# 1. Install the **Python** and **Jupyter** extensions
# 2. Open or create a `.ipynb` file
# 3. Choose the Python interpreter with your environment (e.g., `CEE6501_jupyter`)
# 4. Use:
#    - `Shift+Enter`: Run a cell and move to the next
#    - `Ctrl+Enter`: Run a cell but stay on it
#    - ▶️ Button on the left of each code cell

# %% [markdown]
# ## How to use in browser
#
# You can also run in terminal:
# ```bash
# jupyter lab
# ```

# %% [markdown]
# # 📓 Types of Cells
#
# There are two main cell types:

# %% [markdown]
# ## **Code Cells**
# These are for Python code. You run them to get output, plots, errors, etc.

# %% [markdown]
# ## ✍️ Practice
# Try editing and running the code below:

# %%
print("Write something and run!")
a = 10
b = a + 10
print(b)
# Out:
# Write something and run!
# 20

# %% [markdown]
# ## **Markdown Cells**
#
# These are for formatted text. They use Markdown syntax and can contain:
#
#     Headers (#, ##, etc.)
#
#     Lists
#
#     Bold, italic
#
#     inline code
#
#     LaTeX math:
#
#     Links and Images

# %% [markdown]
# # 🖋️ Markdown Syntax Quick Guide

# %% [markdown]
# ## 📌 Headers
#
# ```
# # H1 – Main Title
# ## H2 – Section
# ### H3 – Subsection
# ```

# %% [markdown]
# ## 🔡 Text Formatting
#
# - **Bold** text: `**bold text**`
# - *Italic* text: `*italic text*`
# - ***Bold and Italic***: `***bold and italic***`

# %% [markdown]
# ## 📋 Lists
#
# **Unordered List:**
# Use a hyphen `-` or asterisk `*`
#
# Example:
# - Apple
# - Banana
# - Cherry
#
# **Ordered List:**
# Use numbers followed by a period `1.`
#
# Example:
# 1. First item
# 2. Second item
# 3. Third item

# %% [markdown]
# ## Bold and Italic
# - **Bold** text: `**bold text**`
# - *Italic* text: `*italic text*`
# - ***Bold and Italic***: `***bold and italic***`
#
# Example:
# This is **bold**, this is *italic*, and this is ***both***.

# %% [markdown]
# ## Inline Code
# Use backticks `` ` `` to format inline code.
#
# Example:
# The variable has a value of 20, `a = 20`.

# %% [markdown]
# ## Code Blocks
# Use triple backticks `` ``` `` to create multi-line code blocks.
#
# Example:
#
# ```python
# def greet(name):
#     return f"Hello, {name}!"
# ```

# %% [markdown]
# ## 🧮 LaTeX Math
#
# Write math using ``$...$`` for inline or ``$$...$$`` for block equations.
#
# Inline Example:
# ``$E = mc^2$`` → $E=mc^2$
#
# Block Example:
# ``$$x = \frac{-b \\pm \\sqrt{b^2 - 4ac}}{2a}$$``
#
# Renders as:
# $$
# x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}
# $$

# %% [markdown]
# ## 🔗 Links
#
# You can embed clickable links and display images using Markdown.
#
# Syntax:
# `` [OpenAI](https://www.openai.com) ``
#
# Example:
# [OpenAI](https://www.openai.com)

# %% [markdown]
# ## 🖼️ Images
#
# Syntax:
# `` ![Alt Text](https://upload.wikimedia.org/wikipedia/commons/3/38/Jupyter_logo.svg)``
#
# Example:
# ![Jupyter Logo](https://upload.wikimedia.org/wikipedia/commons/3/38/Jupyter_logo.svg)

# %% [markdown]
# # 📤 Exporting Notebooks

# %% [markdown]
# ## From VS Code:
# Click on the **"Export..."** button in the top-right to export as:
# - PDF (requires TeX installed)
# - HTML (easier, can then print to PDF)
# - Python script (`.py`)
#
# > To export as PDF:
# - **macOS**: `brew install --cask mactex`
# - **Windows/Linux**: install MiKTeX or TeX Live

# %% [markdown]
# ## From Terminal
#
# You can also export from the command line using:
#
# ```bash
# jupyter nbconvert MyNotebook.ipynb --to pdf
# jupyter nbconvert MyNotebook.ipynb --to html
# jupyter nbconvert MyNotebook.ipynb --to script
# ```
#
# export as html slides:
# ```bash
# jupyter nbconvert --to slides "MyNotebook.ipynb" --post serve
# ```

# %% [markdown]
# # 🧠 Best Practices for Notebooks
#
# - ✅ Restart and Run All periodically
# - ✅ Use Markdown to explain your work
# - ✅ Use clear variable names
# - ✅ Keep notebooks clean and sequential
# - ✅ Save often and use Git for version control

# %% [markdown]
# # ✍️ Practice Challenge
#
# 1. Create a Markdown cell with:
#    - A level-2 header (`##`)
#    - A bullet list of 3 goals you have for this course
#    - A LaTeX formula for kinetic energy:
#      \( E_k = \\frac{1}{2}mv^2 \)
#
# 2. Create a code cell that:
#    - Defines `m = 70` and `v = 5`
#    - Computes and prints kinetic energy

# %%
m = 70  # kg
v = 5   # m/s
E_k = 0.5 * m * v**2
print("Kinetic Energy:", E_k, "Joules")
