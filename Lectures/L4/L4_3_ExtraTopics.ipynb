# %% [markdown]
# # CEE6501 — Lecture 4.3
#
# ## Extra Topics

# %% [markdown]
# ## Learning Objectives
#
# By the end of this lecture, you will be able to:
#
# - ....

# %% [markdown]
# ## Agenda
#
# 1. ...
# 2. ....

# %% [markdown]
# ## Part 1 —
# >Review what we did last lecture
