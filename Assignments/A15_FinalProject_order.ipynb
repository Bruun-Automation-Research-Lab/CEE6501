# %%
import random

people = [
    "Venkat", "Boyang", "John", "Wynn",
    "Chisung", "Patrick", "Ruocheng", "Siyuan", "Anzara"
]

random.seed(30)
random.shuffle(people)

print(people)
# Out:
# ['John', 'Patrick', 'Wynn', 'Boyang', 'Ruocheng', 'Venkat', 'Siyuan', 'Chisung', 'Anzara']
